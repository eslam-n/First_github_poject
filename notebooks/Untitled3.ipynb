# %% [markdown]
# # data visualization

# %%
import pandas as pd

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.1 MB 20.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 13.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 14.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ------------------------------- -------- 5.5/7.0 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------  6.8/7.0 MB 27.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 15.7 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
# ...

# %%
df = pd.read_csv("salary.csv")

# %%
df['salary'].plot(kind="box")
# Out:
# <Axes: >

# %%
df['gender'].value_counts().plot(kind="pie");

# %%
df['age'].plot(kind="hist");

# %%
df.groupby(['departm','gender'])['age'].count().plot(kind='bar');

# %%
df.plot(x='age',y='salary',kind='scatter');

# %%
df.corr(numeric_only=True)
# Out:
#                 salary    gender     years       age  publications
# salary        1.000000 -0.307216  0.307807  0.290491      0.457314
# gender       -0.307216  1.000000 -0.304317 -0.305037     -0.280841
# years         0.307807 -0.304317  1.000000  0.958935      0.339546
# age           0.290491 -0.305037  0.958935  1.000000      0.344125
# publications  0.457314 -0.280841  0.339546  0.344125      1.000000

# %%
df.plot(x='age',y='years',kind='scatter', ylabel='woow',color='green');

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x='age',y='years',kind='scatter', ylabel='woow',color='green')
plt.ylabel('years of exp');
plt.xlabel('ageeee');
plt.title("realtions between age and years")
